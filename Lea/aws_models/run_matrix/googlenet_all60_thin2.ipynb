# %% [markdown]
# #### Using GoogLeNet as a Classify All Model
# Following GoogLeNet implementation from this [blog](https://ai.plainenglish.io/googlenet-inceptionv1-with-tensorflow-9e7f3a161e87)
#
# Use GoogLeNet as a one-step classifier (all labels) for comparing with Yu paper models.  Data resized to 60x60 with n=2 morphological thinning applied.  None type was undersampled randomly to 30,000 samples (same random seed as implemented Yu paper detect model).

# %%
# !pip install pickle5
# Out:
# Requirement already satisfied: pickle5 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (0.0.12)

# %%
# import libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, optimizers, callbacks, Model

import os
import time
import numpy as np
import pandas as pd

import helpers as helper
from keras_model_s3_wrapper import *

import boto3
import pickle5 as pickle
s3 = boto3.resource('s3')
bucket_name = 'wafer-capstone'
my_bucket = s3.Bucket(bucket_name)

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

# %%
# gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333) 
# sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True, gpu_options=gpu_options))

# %%
tf.__version__
# Out:
# '2.3.4'

# %%
tf.config.list_physical_devices(device_type=None)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# specify variables for model
path = 'processed_data/WM-clean60-thin2'
result_path = 'results'

filename = 'WM-clean60-thin2'
option = '-all'
map_column = 'thinMap2'

model_id = 'googlenet'
data_id = 'all60'
note = '-thin2' # -optional

x = 60
y = 60

# %%
# load train, dev, and test sets
# directly from S3 (using boto3 resource)
start = time.time()

train_key = f'{path}/{filename}-train{option}.pkl'
dev_key = f'{path}/{filename}-dev.pkl'
test_key = f'{path}/{filename}-test.pkl'

train = pickle.loads(my_bucket.Object(train_key).get()['Body'].read())
dev = pickle.loads(my_bucket.Object(dev_key).get()['Body'].read())
test = pickle.loads(my_bucket.Object(test_key).get()['Body'].read())

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(train[map_column][0])}")
# Out:
# Wall time: 7.76 seconds
# Train: 47863
# Dev: 25942
# Test: 25943
# Sanity check: [0 1]

# %% [markdown]
# #### Quick EDA

# %%
# train failure type distribution
helper.defect_distribution(train, note='Train Set')

# %%
# dev failure type distribution
helper.defect_distribution(dev, note='Dev Set')

# %%
# test failure type distribution
helper.defect_distribution(test, note='Test Set')

# %% [markdown]
# #### Data set-up

# %%
# prepare inputs
start = time.time()

x_train = np.stack(train[map_column])
x_val = np.stack(dev[map_column])
x_test = np.stack(test[map_column])

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: (#rows, xdim, ydim)
print(x_train.shape)
# Out:
# Wall time: 0.23 seconds
# (47863, 60, 60)

# %%
# expand tensor and repeat 3 times
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.expand_dims(x_train, axis=3, name=None)
x_val = tf.expand_dims(x_val, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 3])
x_train.shape
# Out:
# Wall time: 0.36 seconds
# TensorShape([47863, 60, 60, 1])

# %%
# expand tensor and repeat 3 times
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.repeat(x_train, 3, axis=3)
x_val = tf.repeat(x_val, 3, axis=3)
x_test = tf.repeat(x_test, 3, axis=3)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 3])
x_train.shape
# Out:
# Wall time: 0.74 seconds
# TensorShape([47863, 60, 60, 3])

# %%
# prepare labels for supervised learning
# note: make sure labels are integers if using sparse categorical cross entropy
start = time.time()

y_train = np.asarray(train['classifyLabels']).astype(np.uint8)
y_val = np.asarray(dev['classifyLabels']).astype(np.uint8)
y_test = np.asarray(test['classifyLabels']).astype(np.uint8)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: type = int, min = 0, max = 7
print(type(y_train[0]))
print(min(y_train), min(y_val), min(y_test))
print(max(y_train), max(y_val), max(y_test))
# Out:
# Wall time: 0.00 seconds
# <class 'numpy.uint8'>
# 0 0 0
# 8 8 8

# %% [markdown]
# #### Model

# %%
def inception(x,
              filters_1x1,
              filters_3x3_reduce,
              filters_3x3,
              filters_5x5_reduce,
              filters_5x5,
              filters_pool):
  path1 = layers.Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

  path2 = layers.Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
  path2 = layers.Conv2D(filters_3x3, (1, 1), padding='same', activation='relu')(path2)

  path3 = layers.Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
  path3 = layers.Conv2D(filters_5x5, (1, 1), padding='same', activation='relu')(path3)

  path4 = layers.MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
  path4 = layers.Conv2D(filters_pool, (1, 1), padding='same', activation='relu')(path4)

  return tf.concat([path1, path2, path3, path4], axis=3)

# %%
inp = layers.Input(shape=(x, y, 3))
input_tensor = layers.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=x_train.shape[1:])(inp)

x = layers.Conv2D(64, 7, strides=2, padding='same', activation='relu')(input_tensor)
x = layers.MaxPooling2D(3, strides=2)(x)

x = layers.Conv2D(64, 1, strides=1, padding='same', activation='relu')(x)
x = layers.Conv2D(192, 3, strides=1, padding='same', activation='relu')(x)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=64,
              filters_3x3_reduce=96,
              filters_3x3=128,
              filters_5x5_reduce=16,
              filters_5x5=32,
              filters_pool=32)

x = inception(x,
              filters_1x1=128,
              filters_3x3_reduce=128,
              filters_3x3=192,
              filters_5x5_reduce=32,
              filters_5x5=96,
              filters_pool=64)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=192,
              filters_3x3_reduce=96,
              filters_3x3=208,
              filters_5x5_reduce=16,
              filters_5x5=48,
              filters_pool=64)

aux1 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux1 = layers.Conv2D(128, 1, padding='same', activation='relu')(aux1)
aux1 = layers.Flatten()(aux1)
aux1 = layers.Dense(1024, activation='relu')(aux1)
aux1 = layers.Dropout(0.7)(aux1)
aux1 = layers.Dense(10, activation='softmax')(aux1)

x = inception(x,
              filters_1x1=160,
              filters_3x3_reduce=112,
              filters_3x3=224,
              filters_5x5_reduce=24,
              filters_5x5=64,
              filters_pool=64)

x = inception(x,
              filters_1x1=128,
              filters_3x3_reduce=128,
              filters_3x3=256,
              filters_5x5_reduce=24,
              filters_5x5=64,
              filters_pool=64)

x = inception(x,
              filters_1x1=112,
              filters_3x3_reduce=144,
              filters_3x3=288,
              filters_5x5_reduce=32,
              filters_5x5=64,
              filters_pool=64)

aux2 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux2 = layers.Conv2D(128, 1, padding='same', activation='relu')(aux2)
aux2 = layers.Flatten()(aux2)
aux2 = layers.Dense(1024, activation='relu')(aux2)
aux2 = layers.Dropout(0.7)(aux2)
aux2 = layers.Dense(10, activation='softmax')(aux2)

x = inception(x,
              filters_1x1=256,
              filters_3x3_reduce=160,
              filters_3x3=320,
              filters_5x5_reduce=32,
              filters_5x5=128,
              filters_pool=128)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=256,
              filters_3x3_reduce=160,
              filters_3x3=320,
              filters_5x5_reduce=32,
              filters_5x5=128,
              filters_pool=128)

x = inception(x,
              filters_1x1=384,
              filters_3x3_reduce=192,
              filters_3x3=384,
              filters_5x5_reduce=48,
              filters_5x5=128,
              filters_pool=128)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dropout(0.4)(x)
out = layers.Dense(9, activation='softmax')(x)

# %%
model = Model(inputs = inp, outputs = [out, aux1, aux2])

# %%
model.compile(optimizer='adam', loss=[losses.sparse_categorical_crossentropy, losses.sparse_categorical_crossentropy, losses.sparse_categorical_crossentropy], loss_weights=[1, 0.3, 0.3], metrics=['accuracy'])

# %%
history = model.fit(x_train, [y_train, y_train, y_train], validation_data=(x_val, [y_val, y_val, y_val]), batch_size=64, epochs=30)
# Out:
# Epoch 1/30
#   2/748 [..............................] - ETA: 54s - loss: 3.4459 - dense_4_loss: 2.1360 - dense_1_loss: 2.1209 - dense_3_loss: 2.2452 - dense_4_accuracy: 0.3750 - dense_1_accuracy: 0.4766 - dense_3_accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0512s vs `on_train_batch_end` time: 0.0925s). Check your callbacks.
# 748/748 [==============================] - 130s 173ms/step - loss: 1.2392 - dense_4_loss: 0.7753 - dense_1_loss: 0.7869 - dense_3_loss: 0.7593 - dense_4_accuracy: 0.7683 - dense_1_accuracy: 0.7724 - dense_3_accuracy: 0.7790 - val_loss: 0.3978 - val_dense_4_loss: 0.2505 - val_dense_1_loss: 0.2636 - val_dense_3_loss: 0.2274 - val_dense_4_accuracy: 0.9301 - val_dense_1_accuracy: 0.9322 - val_dense_3_accuracy: 0.9345
# Epoch 2/30
# 748/748 [==============================] - 126s 168ms/step - loss: 0.7290 - dense_4_loss: 0.4493 - dense_1_loss: 0.4938 - dense_3_loss: 0.4385 - dense_4_accuracy: 0.8578 - dense_1_accuracy: 0.8518 - dense_3_accuracy: 0.8646 - val_loss: 0.3328 - val_dense_4_loss: 0.2058 - val_dense_1_loss: 0.2280 - val_dense_3_loss: 0.1951 - val_dense_4_accuracy: 0.9405 - val_dense_1_accuracy: 0.9363 - val_dense_3_accuracy: 0.9445
# Epoch 3/30
# 748/748 [==============================] - 127s 169ms/step - loss: 0.6295 - dense_4_loss: 0.3850 - dense_1_loss: 0.4311 - dense_3_loss: 0.3839 - dense_4_accuracy: 0.8772 - dense_1_accuracy: 0.8669 - dense_3_accuracy: 0.8813 - val_loss: 0.2927 - val_dense_4_loss: 0.1861 - val_dense_1_loss: 0.1881 - val_dense_3_loss: 0.1674 - val_dense_4_accuracy: 0.9460 - val_dense_1_accuracy: 0.9449 - val_dense_3_accuracy: 0.9502
# Epoch 4/30
# 748/748 [==============================] - 128s 171ms/step - loss: 0.5668 - dense_4_loss: 0.3451 - dense_1_loss: 0.3932 - dense_3_loss: 0.3460 - dense_4_accuracy: 0.8904 - dense_1_accuracy: 0.8766 - dense_3_accuracy: 0.8902 - val_loss: 0.3617 - val_dense_4_loss: 0.2352 - val_dense_1_loss: 0.2032 - val_dense_3_loss: 0.2183 - val_dense_4_accuracy: 0.9287 - val_dense_1_accuracy: 0.9374 - val_dense_3_accuracy: 0.9308
# Epoch 5/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.5216 - dense_4_loss: 0.3155 - dense_1_loss: 0.3661 - dense_3_loss: 0.3209 - dense_4_accuracy: 0.8996 - dense_1_accuracy: 0.8846 - dense_3_accuracy: 0.8991 - val_loss: 0.3362 - val_dense_4_loss: 0.2099 - val_dense_1_loss: 0.2277 - val_dense_3_loss: 0.1930 - val_dense_4_accuracy: 0.9445 - val_dense_1_accuracy: 0.9416 - val_dense_3_accuracy: 0.9463
# Epoch 6/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.4953 - dense_4_loss: 0.2996 - dense_1_loss: 0.3460 - dense_3_loss: 0.3061 - dense_4_accuracy: 0.9043 - dense_1_accuracy: 0.8910 - dense_3_accuracy: 0.9032 - val_loss: 0.3223 - val_dense_4_loss: 0.2043 - val_dense_1_loss: 0.2063 - val_dense_3_loss: 0.1869 - val_dense_4_accuracy: 0.9374 - val_dense_1_accuracy: 0.9362 - val_dense_3_accuracy: 0.9397
# Epoch 7/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.4734 - dense_4_loss: 0.2867 - dense_1_loss: 0.3332 - dense_3_loss: 0.2890 - dense_4_accuracy: 0.9084 - dense_1_accuracy: 0.8928 - dense_3_accuracy: 0.9084 - val_loss: 0.3711 - val_dense_4_loss: 0.2312 - val_dense_1_loss: 0.2421 - val_dense_3_loss: 0.2242 - val_dense_4_accuracy: 0.9306 - val_dense_1_accuracy: 0.9291 - val_dense_3_accuracy: 0.9311
# Epoch 8/30
# 748/748 [==============================] - 127s 169ms/step - loss: 0.4488 - dense_4_loss: 0.2706 - dense_1_loss: 0.3166 - dense_3_loss: 0.2773 - dense_4_accuracy: 0.9121 - dense_1_accuracy: 0.8982 - dense_3_accuracy: 0.9110 - val_loss: 0.3035 - val_dense_4_loss: 0.1804 - val_dense_1_loss: 0.2311 - val_dense_3_loss: 0.1790 - val_dense_4_accuracy: 0.9470 - val_dense_1_accuracy: 0.9378 - val_dense_3_accuracy: 0.9460
# Epoch 9/30
# 748/748 [==============================] - 126s 169ms/step - loss: 0.4290 - dense_4_loss: 0.2586 - dense_1_loss: 0.3029 - dense_3_loss: 0.2650 - dense_4_accuracy: 0.9159 - dense_1_accuracy: 0.9022 - dense_3_accuracy: 0.9152 - val_loss: 0.2529 - val_dense_4_loss: 0.1564 - val_dense_1_loss: 0.1663 - val_dense_3_loss: 0.1554 - val_dense_4_accuracy: 0.9511 - val_dense_1_accuracy: 0.9492 - val_dense_3_accuracy: 0.9513
# Epoch 10/30
# 748/748 [==============================] - 125s 168ms/step - loss: 0.4138 - dense_4_loss: 0.2491 - dense_1_loss: 0.2916 - dense_3_loss: 0.2574 - dense_4_accuracy: 0.9191 - dense_1_accuracy: 0.9055 - dense_3_accuracy: 0.9176 - val_loss: 0.2597 - val_dense_4_loss: 0.1606 - val_dense_1_loss: 0.1743 - val_dense_3_loss: 0.1561 - val_dense_4_accuracy: 0.9492 - val_dense_1_accuracy: 0.9459 - val_dense_3_accuracy: 0.9502
# Epoch 11/30
# 748/748 [==============================] - 127s 170ms/step - loss: 0.3900 - dense_4_loss: 0.2335 - dense_1_loss: 0.2811 - dense_3_loss: 0.2404 - dense_4_accuracy: 0.9242 - dense_1_accuracy: 0.9087 - dense_3_accuracy: 0.9223 - val_loss: 0.2406 - val_dense_4_loss: 0.1490 - val_dense_1_loss: 0.1564 - val_dense_3_loss: 0.1488 - val_dense_4_accuracy: 0.9530 - val_dense_1_accuracy: 0.9509 - val_dense_3_accuracy: 0.9536
# Epoch 12/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.3780 - dense_4_loss: 0.2259 - dense_1_loss: 0.2717 - dense_3_loss: 0.2356 - dense_4_accuracy: 0.9264 - dense_1_accuracy: 0.9120 - dense_3_accuracy: 0.9248 - val_loss: 0.2582 - val_dense_4_loss: 0.1619 - val_dense_1_loss: 0.1590 - val_dense_3_loss: 0.1619 - val_dense_4_accuracy: 0.9500 - val_dense_1_accuracy: 0.9519 - val_dense_3_accuracy: 0.9504
# Epoch 13/30
# 748/748 [==============================] - 127s 170ms/step - loss: 0.3562 - dense_4_loss: 0.2126 - dense_1_loss: 0.2564 - dense_3_loss: 0.2222 - dense_4_accuracy: 0.9302 - dense_1_accuracy: 0.9163 - dense_3_accuracy: 0.9273 - val_loss: 0.2826 - val_dense_4_loss: 0.1834 - val_dense_1_loss: 0.1612 - val_dense_3_loss: 0.1695 - val_dense_4_accuracy: 0.9443 - val_dense_1_accuracy: 0.9515 - val_dense_3_accuracy: 0.9477
# Epoch 14/30
# 748/748 [==============================] - 125s 167ms/step - loss: 0.3449 - dense_4_loss: 0.2056 - dense_1_loss: 0.2494 - dense_3_loss: 0.2149 - dense_4_accuracy: 0.9331 - dense_1_accuracy: 0.9197 - dense_3_accuracy: 0.9298 - val_loss: 0.3285 - val_dense_4_loss: 0.2076 - val_dense_1_loss: 0.1997 - val_dense_3_loss: 0.2034 - val_dense_4_accuracy: 0.9342 - val_dense_1_accuracy: 0.9370 - val_dense_3_accuracy: 0.9321
# Epoch 15/30
# 748/748 [==============================] - 126s 168ms/step - loss: 0.3302 - dense_4_loss: 0.1966 - dense_1_loss: 0.2414 - dense_3_loss: 0.2041 - dense_4_accuracy: 0.9363 - dense_1_accuracy: 0.9214 - dense_3_accuracy: 0.9331 - val_loss: 0.2718 - val_dense_4_loss: 0.1671 - val_dense_1_loss: 0.1790 - val_dense_3_loss: 0.1701 - val_dense_4_accuracy: 0.9502 - val_dense_1_accuracy: 0.9432 - val_dense_3_accuracy: 0.9475
# Epoch 16/30
# 748/748 [==============================] - 126s 169ms/step - loss: 0.3094 - dense_4_loss: 0.1824 - dense_1_loss: 0.2309 - dense_3_loss: 0.1924 - dense_4_accuracy: 0.9402 - dense_1_accuracy: 0.9237 - dense_3_accuracy: 0.9366 - val_loss: 0.2884 - val_dense_4_loss: 0.1819 - val_dense_1_loss: 0.1840 - val_dense_3_loss: 0.1712 - val_dense_4_accuracy: 0.9424 - val_dense_1_accuracy: 0.9438 - val_dense_3_accuracy: 0.9453
# Epoch 17/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.2948 - dense_4_loss: 0.1738 - dense_1_loss: 0.2192 - dense_3_loss: 0.1842 - dense_4_accuracy: 0.9426 - dense_1_accuracy: 0.9281 - dense_3_accuracy: 0.9401 - val_loss: 0.2544 - val_dense_4_loss: 0.1593 - val_dense_1_loss: 0.1629 - val_dense_3_loss: 0.1542 - val_dense_4_accuracy: 0.9530 - val_dense_1_accuracy: 0.9508 - val_dense_3_accuracy: 0.9536
# Epoch 18/30
# 748/748 [==============================] - 127s 170ms/step - loss: 0.2823 - dense_4_loss: 0.1656 - dense_1_loss: 0.2113 - dense_3_loss: 0.1777 - dense_4_accuracy: 0.9454 - dense_1_accuracy: 0.9303 - dense_3_accuracy: 0.9423 - val_loss: 0.3785 - val_dense_4_loss: 0.2515 - val_dense_1_loss: 0.1976 - val_dense_3_loss: 0.2258 - val_dense_4_accuracy: 0.9210 - val_dense_1_accuracy: 0.9372 - val_dense_3_accuracy: 0.9280
# Epoch 19/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.2739 - dense_4_loss: 0.1615 - dense_1_loss: 0.2025 - dense_3_loss: 0.1725 - dense_4_accuracy: 0.9464 - dense_1_accuracy: 0.9332 - dense_3_accuracy: 0.9447 - val_loss: 0.2618 - val_dense_4_loss: 0.1650 - val_dense_1_loss: 0.1635 - val_dense_3_loss: 0.1593 - val_dense_4_accuracy: 0.9495 - val_dense_1_accuracy: 0.9517 - val_dense_3_accuracy: 0.9535
# Epoch 20/30
# 748/748 [==============================] - 126s 169ms/step - loss: 0.2627 - dense_4_loss: 0.1535 - dense_1_loss: 0.1997 - dense_3_loss: 0.1644 - dense_4_accuracy: 0.9490 - dense_1_accuracy: 0.9334 - dense_3_accuracy: 0.9455 - val_loss: 0.3323 - val_dense_4_loss: 0.2105 - val_dense_1_loss: 0.2100 - val_dense_3_loss: 0.1958 - val_dense_4_accuracy: 0.9320 - val_dense_1_accuracy: 0.9344 - val_dense_3_accuracy: 0.9370
# Epoch 21/30
# 748/748 [==============================] - 125s 167ms/step - loss: 0.2471 - dense_4_loss: 0.1446 - dense_1_loss: 0.1885 - dense_3_loss: 0.1533 - dense_4_accuracy: 0.9529 - dense_1_accuracy: 0.9385 - dense_3_accuracy: 0.9492 - val_loss: 0.3231 - val_dense_4_loss: 0.2100 - val_dense_1_loss: 0.1847 - val_dense_3_loss: 0.1924 - val_dense_4_accuracy: 0.9410 - val_dense_1_accuracy: 0.9455 - val_dense_3_accuracy: 0.9445
# Epoch 22/30
# 748/748 [==============================] - 125s 167ms/step - loss: 0.2387 - dense_4_loss: 0.1381 - dense_1_loss: 0.1857 - dense_3_loss: 0.1495 - dense_4_accuracy: 0.9540 - dense_1_accuracy: 0.9388 - dense_3_accuracy: 0.9515 - val_loss: 0.2900 - val_dense_4_loss: 0.1829 - val_dense_1_loss: 0.1767 - val_dense_3_loss: 0.1801 - val_dense_4_accuracy: 0.9468 - val_dense_1_accuracy: 0.9468 - val_dense_3_accuracy: 0.9483
# Epoch 23/30
# 748/748 [==============================] - 127s 169ms/step - loss: 0.2325 - dense_4_loss: 0.1358 - dense_1_loss: 0.1796 - dense_3_loss: 0.1426 - dense_4_accuracy: 0.9547 - dense_1_accuracy: 0.9403 - dense_3_accuracy: 0.9529 - val_loss: 0.2667 - val_dense_4_loss: 0.1657 - val_dense_1_loss: 0.1705 - val_dense_3_loss: 0.1662 - val_dense_4_accuracy: 0.9527 - val_dense_1_accuracy: 0.9504 - val_dense_3_accuracy: 0.9536
# Epoch 24/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.2102 - dense_4_loss: 0.1201 - dense_1_loss: 0.1673 - dense_3_loss: 0.1329 - dense_4_accuracy: 0.9602 - dense_1_accuracy: 0.9445 - dense_3_accuracy: 0.9567 - val_loss: 0.2882 - val_dense_4_loss: 0.1797 - val_dense_1_loss: 0.1790 - val_dense_3_loss: 0.1827 - val_dense_4_accuracy: 0.9496 - val_dense_1_accuracy: 0.9500 - val_dense_3_accuracy: 0.9492
# Epoch 25/30
# 748/748 [==============================] - 127s 170ms/step - loss: 0.2190 - dense_4_loss: 0.1256 - dense_1_loss: 0.1738 - dense_3_loss: 0.1375 - dense_4_accuracy: 0.9577 - dense_1_accuracy: 0.9415 - dense_3_accuracy: 0.9548 - val_loss: 0.2916 - val_dense_4_loss: 0.1826 - val_dense_1_loss: 0.1801 - val_dense_3_loss: 0.1832 - val_dense_4_accuracy: 0.9503 - val_dense_1_accuracy: 0.9515 - val_dense_3_accuracy: 0.9482
# Epoch 26/30
# 748/748 [==============================] - 124s 166ms/step - loss: 0.2002 - dense_4_loss: 0.1145 - dense_1_loss: 0.1607 - dense_3_loss: 0.1248 - dense_4_accuracy: 0.9616 - dense_1_accuracy: 0.9461 - dense_3_accuracy: 0.9581 - val_loss: 0.3839 - val_dense_4_loss: 0.2506 - val_dense_1_loss: 0.2117 - val_dense_3_loss: 0.2325 - val_dense_4_accuracy: 0.9358 - val_dense_1_accuracy: 0.9388 - val_dense_3_accuracy: 0.9397
# Epoch 27/30
# 748/748 [==============================] - 125s 168ms/step - loss: 0.1928 - dense_4_loss: 0.1103 - dense_1_loss: 0.1551 - dense_3_loss: 0.1199 - dense_4_accuracy: 0.9653 - dense_1_accuracy: 0.9487 - dense_3_accuracy: 0.9607 - val_loss: 0.4122 - val_dense_4_loss: 0.2690 - val_dense_1_loss: 0.2233 - val_dense_3_loss: 0.2539 - val_dense_4_accuracy: 0.9249 - val_dense_1_accuracy: 0.9350 - val_dense_3_accuracy: 0.9261
# Epoch 28/30
# 748/748 [==============================] - 126s 168ms/step - loss: 0.1988 - dense_4_loss: 0.1135 - dense_1_loss: 0.1585 - dense_3_loss: 0.1257 - dense_4_accuracy: 0.9620 - dense_1_accuracy: 0.9475 - dense_3_accuracy: 0.9587 - val_loss: 0.3916 - val_dense_4_loss: 0.2464 - val_dense_1_loss: 0.2563 - val_dense_3_loss: 0.2275 - val_dense_4_accuracy: 0.9298 - val_dense_1_accuracy: 0.9303 - val_dense_3_accuracy: 0.9325
# Epoch 29/30
# 748/748 [==============================] - 125s 166ms/step - loss: 0.1896 - dense_4_loss: 0.1076 - dense_1_loss: 0.1533 - dense_3_loss: 0.1200 - dense_4_accuracy: 0.9649 - dense_1_accuracy: 0.9503 - dense_3_accuracy: 0.9613 - val_loss: 0.3372 - val_dense_4_loss: 0.2072 - val_dense_1_loss: 0.2114 - val_dense_3_loss: 0.2222 - val_dense_4_accuracy: 0.9492 - val_dense_1_accuracy: 0.9433 - val_dense_3_accuracy: 0.9458
# Epoch 30/30
# 748/748 [==============================] - 127s 169ms/step - loss: 0.1770 - dense_4_loss: 0.1001 - dense_1_loss: 0.1463 - dense_3_loss: 0.1101 - dense_4_accuracy: 0.9673 - dense_1_accuracy: 0.9515 - dense_3_accuracy: 0.9639 - val_loss: 0.4161 - val_dense_4_loss: 0.2590 - val_dense_1_loss: 0.2626 - val_dense_3_loss: 0.2610 - val_dense_4_accuracy: 0.9311 - val_dense_1_accuracy: 0.9262 - val_dense_3_accuracy: 0.9296

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train','Val'])

axs[1].plot(history.history['dense_4_accuracy'])
axs[1].plot(history.history['val_dense_4_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# #### Model results

# %%
# save model to S3
s3_save_keras_model(model, f'{model_id}-{data_id}{note}')
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /tmp/tmp2083s0vy/googlenet-all60-thin2/assets

# %%
# compute model results on test set
start = time.time()
results = model.evaluate(x_test, y_test)
print("Wall time: {:.2f} seconds".format(time.time() - start))
print(results)
# Out:
# 811/811 [==============================] - 20s 24ms/step - loss: 0.4111 - dense_4_loss: 0.2561 - dense_1_loss: 0.2615 - dense_3_loss: 0.2552 - dense_4_accuracy: 0.9329 - dense_1_accuracy: 0.9253 - dense_3_accuracy: 0.9320
# Wall time: 20.90 seconds
# [0.41114434599876404, 0.256149560213089, 0.2614723742008209, 0.25517722964286804, 0.9328528046607971, 0.9252592325210571, 0.9320048093795776]

# %%
# generate predictions for model analysis
start = time.time()
pred = model.predict(x_test)
y_pred = np.argmax(pred[0], axis=1)
predictions = [y_pred, pred]
print("Wall time: {} seconds".format(time.time() - start))
# Out:
# Wall time: 18.368011951446533 seconds

# %%
# save predictions
# save to local instance
with open(f'{result_path}/{model_id}-{data_id}{note}.pkl', "wb") as f:
    pickle.dump(predictions, f)

# %%
# plot confusion matrix
helper.plot_confusion_matrix(y_test, y_pred, mode='all', normalize=True)

# %%
# plot confusion matrix counts
helper.plot_confusion_matrix(y_test, y_pred, mode='all', normalize=False)
