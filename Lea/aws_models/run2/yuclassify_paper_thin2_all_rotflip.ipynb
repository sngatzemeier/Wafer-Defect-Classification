# %% [markdown]
# #### Classify model from Yu, et al
# Implementation of the classification model from the Yu, et al [paper](https://drive.google.com/file/d/1nYl4w41CAcj8XwTEdVwcD5lVheUFIHVy/view?usp=sharing)
#
# Difference(s) from paper:
# - Used to classify all defects, including none
# - Run for 30 epochs instead of 80
# - Resized to 224x224 with 7x7 median filter applied, followed by n=2 morphological thinning
#
# None is randomly undersampled to 30,000.

# %%
# !pip install pickle5
# Out:
# Requirement already satisfied: pickle5 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (0.0.12)

# %%
# import libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, optimizers, regularizers, callbacks

import os
import time
import numpy as np
import pandas as pd

import helpers as helper
from keras_model_s3_wrapper import *

import boto3
import pickle5 as pickle
s3 = boto3.resource('s3')
bucket_name = 'wafer-capstone'
my_bucket = s3.Bucket(bucket_name)

# %%
tf.__version__
# Out:
# '2.3.4'

# %%
tf.config.list_physical_devices(device_type=None)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:1', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:2', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:3', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
# specify variables for model
path = 'processed_data/WM-clean-paper'
result_path = 'results2'
model_path = '../saved_models'

filename = 'WM-clean-paper'
map_column = 'thinMap2'

model_id = 'yuclassify'
data_id = 'paper-thin2-all'
note = '-rotflip' # -optional

# %%
# load dev and test sets
# directly from S3 (using boto3 resource)
# binarize and apply n=2 morphological thinning
import cv2
from skimage.morphology import skeletonize, thin
start = time.time()

dev_key = f'{path}/{filename}-dev.pkl'
test_key = f'{path}/{filename}-test.pkl'

dev = pickle.loads(my_bucket.Object(dev_key).get()['Body'].read())
test = pickle.loads(my_bucket.Object(test_key).get()['Body'].read())

def preprocess(x):
    ret, thresh_img = cv2.threshold(x, 1, 1, cv2.THRESH_BINARY)
    y = thin(thresh_img, 2)
    return y

dev['thinMap2'] = dev.waferMap224.apply(lambda x: preprocess(x))
dev['thinMap2'] = dev.thinMap2.apply(lambda x: x.astype(np.uint8))

test['thinMap2'] = test.waferMap224.apply(lambda x: preprocess(x))
test['thinMap2'] = test.thinMap2.apply(lambda x: x.astype(np.uint8))

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(dev['thinMap2'][0])}")
# Out:
# Wall time: 250.08 seconds
# Dev: 25942
# Test: 25943
# Sanity check: [0 1]

# %%
# load train
# directly from S3 (using boto3 resource)
# binarize and apply n=2 morphological thinning
from skimage.transform import resize as sk_resize
from skimage.util import img_as_ubyte
start = time.time()

train_key = f'processed_data/WM-clean224/WM-clean224-train-all.pkl'
train = pickle.loads(my_bucket.Object(train_key).get()['Body'].read())

# remove augmented samples
train = train[train.ID != 'A'].reset_index(drop=True)

def filter_thin(x):
    y = cv2.medianBlur(x, 7)
    ret, thresh_img = cv2.threshold(y, 1, 1, cv2.THRESH_BINARY)
    z = thin(thresh_img, 2)
    return z

train['thinMap2'] = train.waferMap224.apply(lambda x: filter_thin(x))
train['thinMap2'] = train.thinMap2.apply(lambda x: x.astype(np.uint8))

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")

print(f"Sanity check: {np.unique(train['thinMap2'][0])}")
# Out:
# Wall time: 336.07 seconds
# Train: 47863
# Sanity check: [0 1]

# %% [markdown]
# #### Quick EDA

# %%
# train failure type distribution
helper.defect_distribution(train, note='Train Set')

# %%
# dev failure type distribution
helper.defect_distribution(dev, note='Dev Set')

# %%
# test failure type distribution
helper.defect_distribution(test, note='Test Set')

# %% [markdown]
# #### Data set-up

# %%
# prepare inputs
start = time.time()

x_train = np.stack(train[map_column])
x_val = np.stack(dev[map_column])
x_test = np.stack(test[map_column])

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: (#rows, xdim, ydim)
print(x_train.shape)
# Out:
# Wall time: 2.16 seconds
# (47863, 224, 224)

# %%
# expand tensor and create dummy dimension at axis 3
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.expand_dims(x_train, axis=3, name=None)
x_val = tf.expand_dims(x_val, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 1])
x_train.shape
# Out:
# Wall time: 7.08 seconds
# TensorShape([47863, 224, 224, 1])

# %%
# prepare labels for supervised learning
# note: make sure labels are integers if using sparse categorical cross entropy
start = time.time()

y_train = np.asarray(train['classifyLabels']).astype(np.uint8)
y_val = np.asarray(dev['classifyLabels']).astype(np.uint8)
y_test = np.asarray(test['classifyLabels']).astype(np.uint8)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: type = int, min = 0, max = 7
print(type(y_train[0]))
print(min(y_train), min(y_val), min(y_test))
print(max(y_train), max(y_val), max(y_test))
# Out:
# Wall time: 0.00 seconds
# <class 'numpy.uint8'>
# 0 0 0
# 8 8 8

# %% [markdown]
# #### Model

# %%
# define model architecture

model = models.Sequential()
model.add(layers.Input(shape=(224, 224, 1)))
model.add(layers.experimental.preprocessing.RandomFlip(seed=424))
model.add(layers.experimental.preprocessing.RandomRotation(1, fill_mode='constant', interpolation='nearest', seed=424))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu', input_shape=x_train.shape[1:]))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dense(1024, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(9, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# random_flip (RandomFlip)     (None, 224, 224, 1)       0
# _________________________________________________________________
# random_rotation (RandomRotat (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 74, 74, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 74, 74, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 9225
# =================================================================
# Total params: 38,197,097
# Trainable params: 38,197,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set model optimizer and metrics
opt = optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
# run model
start = time.time()

history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=128, epochs=30)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Epoch 1/30
#   2/374 [..............................] - ETA: 16s - loss: 3.5977 - accuracy: 0.3828WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0296s vs `on_train_batch_end` time: 0.0577s). Check your callbacks.
# 374/374 [==============================] - 39s 105ms/step - loss: 0.7078 - accuracy: 0.8209 - val_loss: 0.1917 - val_accuracy: 0.9395
# Epoch 2/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.3147 - accuracy: 0.9010 - val_loss: 0.2038 - val_accuracy: 0.9345
# Epoch 3/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2890 - accuracy: 0.9108 - val_loss: 0.1435 - val_accuracy: 0.9629
# Epoch 4/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2650 - accuracy: 0.9198 - val_loss: 0.1440 - val_accuracy: 0.9639
# Epoch 5/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2556 - accuracy: 0.9247 - val_loss: 0.1534 - val_accuracy: 0.9603
# Epoch 6/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2440 - accuracy: 0.9298 - val_loss: 0.1866 - val_accuracy: 0.9497
# Epoch 7/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2442 - accuracy: 0.9322 - val_loss: 0.1455 - val_accuracy: 0.9672
# Epoch 8/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2415 - accuracy: 0.9320 - val_loss: 0.1508 - val_accuracy: 0.9652
# Epoch 9/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2410 - accuracy: 0.9346 - val_loss: 0.1421 - val_accuracy: 0.9686
# Epoch 10/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2419 - accuracy: 0.9353 - val_loss: 0.1616 - val_accuracy: 0.9616
# Epoch 11/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2445 - accuracy: 0.9363 - val_loss: 0.1576 - val_accuracy: 0.9650
# Epoch 12/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2464 - accuracy: 0.9353 - val_loss: 0.1450 - val_accuracy: 0.9712
# Epoch 13/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2435 - accuracy: 0.9383 - val_loss: 0.1709 - val_accuracy: 0.9618
# Epoch 14/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2438 - accuracy: 0.9384 - val_loss: 0.1554 - val_accuracy: 0.9692
# Epoch 15/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2474 - accuracy: 0.9366 - val_loss: 0.1786 - val_accuracy: 0.9614
# Epoch 16/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2491 - accuracy: 0.9363 - val_loss: 0.1553 - val_accuracy: 0.9721
# Epoch 17/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2542 - accuracy: 0.9369 - val_loss: 0.1576 - val_accuracy: 0.9693
# Epoch 18/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2563 - accuracy: 0.9374 - val_loss: 0.1666 - val_accuracy: 0.9675
# Epoch 19/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2545 - accuracy: 0.9385 - val_loss: 0.1650 - val_accuracy: 0.9709
# Epoch 20/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2574 - accuracy: 0.9386 - val_loss: 0.1647 - val_accuracy: 0.9715
# Epoch 21/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2550 - accuracy: 0.9393 - val_loss: 0.1664 - val_accuracy: 0.9712
# Epoch 22/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2602 - accuracy: 0.9395 - val_loss: 0.2196 - val_accuracy: 0.9526
# Epoch 23/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2609 - accuracy: 0.9374 - val_loss: 0.1662 - val_accuracy: 0.9711
# Epoch 24/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2628 - accuracy: 0.9391 - val_loss: 0.1898 - val_accuracy: 0.9646
# Epoch 25/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2644 - accuracy: 0.9380 - val_loss: 0.1876 - val_accuracy: 0.9626
# Epoch 26/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2690 - accuracy: 0.9378 - val_loss: 0.2056 - val_accuracy: 0.9592
# Epoch 27/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2685 - accuracy: 0.9391 - val_loss: 0.1936 - val_accuracy: 0.9632
# Epoch 28/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2757 - accuracy: 0.9360 - val_loss: 0.1799 - val_accuracy: 0.9695
# Epoch 29/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2768 - accuracy: 0.9358 - val_loss: 0.1999 - val_accuracy: 0.9614
# Epoch 30/30
# 374/374 [==============================] - 37s 100ms/step - loss: 0.2821 - accuracy: 0.9353 - val_loss: 0.1983 - val_accuracy: 0.9635
# Wall time: 1131.57 seconds

# %%
# visualize accuracy and loss history
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].legend(['Train', 'Val'])

axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# #### Model results

# %%
# save model to S3
s3_save_keras_model(model, f'{model_id}-{data_id}{note}')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpqdrghx2s/yuclassify-paper-thin2-all-rotflip/assets

# %%
# compute model results on test set
start = time.time()
results = model.evaluate(x_test, y_test)
print("Wall time: {:.2f} seconds".format(time.time() - start))
print(results)
# Out:
# 811/811 [==============================] - 6s 8ms/step - loss: 0.1954 - accuracy: 0.9644
# Wall time: 7.40 seconds
# [0.1954144686460495, 0.9644219875335693]

# %%
# generate predictions for model analysis
start = time.time()
y_pred = model.predict(x_test)
y_max = np.argmax(y_pred, axis=1).astype(np.uint8)
predictions = [y_max, y_pred]
print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Wall time: 5.00 seconds

# %%
# save predictions to local instance
with open(f'{result_path}/{model_id}-{data_id}{note}.pkl', "wb") as f:
    pickle.dump(predictions, f)

# %%
# plot confusion matrix
helper.plot_confusion_matrix(y_test, y_max, mode='all', normalize=True)

# %%
# plot confusion matrix counts
helper.plot_confusion_matrix(y_test, y_max, mode='all', normalize=False)
