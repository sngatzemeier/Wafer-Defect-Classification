# %% [markdown]
# #### Classify model from Yu, et al
# Implementation of the classification model from the Yu, et al [paper](https://drive.google.com/file/d/1nYl4w41CAcj8XwTEdVwcD5lVheUFIHVy/view?usp=sharing)
#
# Difference(s) from paper:
# - Ran for 30 epochs instead of 80
# - Resized to 224x224 with 7x7 median filter applied, followed by n=2 morphological thinning

# %%
# !pip install pickle5
# Out:
# Requirement already satisfied: pickle5 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (0.0.12)

# %%
# import libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, optimizers, regularizers, callbacks

import os
import time
import numpy as np
import pandas as pd

import helpers as helper
from keras_model_s3_wrapper import *

import boto3
import pickle5 as pickle
s3 = boto3.resource('s3')
bucket_name = 'wafer-capstone'
my_bucket = s3.Bucket(bucket_name)

# %%
tf.__version__
# Out:
# '2.3.4'

# %%
tf.config.list_physical_devices(device_type=None)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# specify variables for model
path = 'processed_data/WM-clean-paper'
result_path = 'results2'
model_path = '../saved_models'

filename = 'WM-clean-paper'
option = '-classify' # -classify, -knn
map_column = 'thinMap2'

model_id = 'yuclassify'
data_id = 'paper-thin2'
note = '' # -optional

# %%
# load train, dev, and test sets
# directly from S3 (using boto3 resource)
start = time.time()

train_key = f'{path}/{filename}-train{option}.pkl'
dev_key = f'{path}/{filename}-dev.pkl'
test_key = f'{path}/{filename}-test.pkl'

train = pickle.loads(my_bucket.Object(train_key).get()['Body'].read())
dev = pickle.loads(my_bucket.Object(dev_key).get()['Body'].read())
test = pickle.loads(my_bucket.Object(test_key).get()['Body'].read())

# remove nones from dev and test

dev = dev[dev.classifyLabels != 8].reset_index(drop=True)
test = test[test.classifyLabels != 8].reset_index(drop=True)

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(train['waferMap224'][0])}")
# Out:
# Wall time: 49.34 seconds
# Train: 17863
# Dev: 3828
# Test: 3828
# Sanity check: [0 1 2]

# %%
# binarize and apply n=2 morphological thinning
import cv2
from skimage.morphology import skeletonize, thin
start = time.time()

def preprocess(x):
    ret, thresh_img = cv2.threshold(x, 1, 1, cv2.THRESH_BINARY)
    y = thin(thresh_img, 2)
    return y

train['thinMap2'] = train.waferMap224.apply(lambda x: preprocess(x))
train['thinMap2'] = train.thinMap2.apply(lambda x: x.astype(np.uint8))

dev['thinMap2'] = dev.waferMap224.apply(lambda x: preprocess(x))
dev['thinMap2'] = dev.thinMap2.apply(lambda x: x.astype(np.uint8))

test['thinMap2'] = test.waferMap224.apply(lambda x: preprocess(x))
test['thinMap2'] = test.thinMap2.apply(lambda x: x.astype(np.uint8))

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(train[map_column][0])}")
# Out:
# Wall time: 103.09 seconds
# Train: 17863
# Dev: 3828
# Test: 3828
# Sanity check: [0 1]

# %% [markdown]
# #### Quick EDA

# %%
# train failure type distribution
helper.defect_distribution(train, note='Train Set')

# %%
# dev failure type distribution
helper.defect_distribution(dev, note='Dev Set')

# %%
# test failure type distribution
helper.defect_distribution(test, note='Test Set')

# %% [markdown]
# #### Data set-up

# %%
# prepare inputs
start = time.time()

x_train = np.stack(train[map_column])
x_val = np.stack(dev[map_column])
x_test = np.stack(test[map_column])

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: (#rows, xdim, ydim)
print(x_train.shape)
# Out:
# Wall time: 0.41 seconds
# (17863, 224, 224)

# %%
# expand tensor and create dummy dimension at axis 3
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.expand_dims(x_train, axis=3, name=None)
x_val = tf.expand_dims(x_val, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 1])
x_train.shape
# Out:
# Wall time: 2.02 seconds
# TensorShape([17863, 224, 224, 1])

# %%
# prepare labels for supervised learning
# note: make sure labels are integers if using sparse categorical cross entropy
start = time.time()

y_train = np.asarray(train['classifyLabels']).astype(np.uint8)
y_val = np.asarray(dev['classifyLabels']).astype(np.uint8)
y_test = np.asarray(test['classifyLabels']).astype(np.uint8)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: type = int, min = 0, max = 7
print(type(y_train[0]))
print(min(y_train), min(y_val), min(y_test))
print(max(y_train), max(y_val), max(y_test))
# Out:
# Wall time: 0.00 seconds
# <class 'numpy.uint8'>
# 0 0 0
# 7 7 7

# %% [markdown]
# #### Model

# %%
# define model architecture

model = models.Sequential()
model.add(layers.Input(shape=(224, 224, 1)))
model.add(layers.experimental.preprocessing.RandomFlip(seed=424))
model.add(layers.experimental.preprocessing.RandomRotation(1, fill_mode='constant', interpolation='nearest', seed=424))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu', input_shape=x_train.shape[1:]))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dense(1024, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(8, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# random_flip (RandomFlip)     (None, 224, 224, 1)       0
# _________________________________________________________________
# random_rotation (RandomRotat (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 74, 74, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 74, 74, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 8200
# =================================================================
# Total params: 38,196,072
# Trainable params: 38,196,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set model optimizer and metrics
opt = optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
# run model
start = time.time()

history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=128, epochs=30)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Epoch 1/30
#   2/140 [..............................] - ETA: 21s - loss: 4.4389 - accuracy: 0.2188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0823s vs `on_train_batch_end` time: 0.2191s). Check your callbacks.
# 140/140 [==============================] - 46s 329ms/step - loss: 1.2423 - accuracy: 0.6051 - val_loss: 0.5200 - val_accuracy: 0.8072
# Epoch 2/30
# 140/140 [==============================] - 45s 325ms/step - loss: 0.4484 - accuracy: 0.8368 - val_loss: 0.4021 - val_accuracy: 0.8435
# Epoch 3/30
# 140/140 [==============================] - 47s 335ms/step - loss: 0.3716 - accuracy: 0.8679 - val_loss: 0.3014 - val_accuracy: 0.8929
# Epoch 4/30
# 140/140 [==============================] - 47s 337ms/step - loss: 0.3142 - accuracy: 0.8917 - val_loss: 0.2763 - val_accuracy: 0.9046
# Epoch 5/30
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2928 - accuracy: 0.8998 - val_loss: 0.2482 - val_accuracy: 0.9169
# Epoch 6/30
# 140/140 [==============================] - 47s 337ms/step - loss: 0.2760 - accuracy: 0.9087 - val_loss: 0.2502 - val_accuracy: 0.9190
# Epoch 7/30
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2702 - accuracy: 0.9104 - val_loss: 0.2369 - val_accuracy: 0.9248
# Epoch 8/30
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2734 - accuracy: 0.9109 - val_loss: 0.2482 - val_accuracy: 0.9214
# Epoch 9/30
# 140/140 [==============================] - 47s 337ms/step - loss: 0.2609 - accuracy: 0.9156 - val_loss: 0.2725 - val_accuracy: 0.9117
# Epoch 10/30
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2660 - accuracy: 0.9152 - val_loss: 0.2584 - val_accuracy: 0.9188
# Epoch 11/30
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2618 - accuracy: 0.9165 - val_loss: 0.2539 - val_accuracy: 0.9133
# Epoch 12/30
# 140/140 [==============================] - 47s 336ms/step - loss: 0.2604 - accuracy: 0.9198 - val_loss: 0.2322 - val_accuracy: 0.9297
# Epoch 13/30
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2536 - accuracy: 0.9223 - val_loss: 0.2401 - val_accuracy: 0.9235
# Epoch 14/30
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2641 - accuracy: 0.9198 - val_loss: 0.2292 - val_accuracy: 0.9300
# Epoch 15/30
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2548 - accuracy: 0.9238 - val_loss: 0.2311 - val_accuracy: 0.9313
# Epoch 16/30
# 140/140 [==============================] - 46s 329ms/step - loss: 0.2616 - accuracy: 0.9206 - val_loss: 0.2393 - val_accuracy: 0.9310
# Epoch 17/30
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2546 - accuracy: 0.9217 - val_loss: 0.2389 - val_accuracy: 0.9282
# Epoch 18/30
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2581 - accuracy: 0.9234 - val_loss: 0.2478 - val_accuracy: 0.9287
# Epoch 19/30
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2631 - accuracy: 0.9220 - val_loss: 0.2725 - val_accuracy: 0.9169
# Epoch 20/30
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2520 - accuracy: 0.9283 - val_loss: 0.2410 - val_accuracy: 0.9305
# Epoch 21/30
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2626 - accuracy: 0.9254 - val_loss: 0.2374 - val_accuracy: 0.9303
# Epoch 22/30
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2652 - accuracy: 0.9246 - val_loss: 0.2476 - val_accuracy: 0.9316
# Epoch 23/30
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2655 - accuracy: 0.9230 - val_loss: 0.2494 - val_accuracy: 0.9292
# Epoch 24/30
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2689 - accuracy: 0.9247 - val_loss: 0.2425 - val_accuracy: 0.9378
# Epoch 25/30
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2606 - accuracy: 0.9277 - val_loss: 0.2509 - val_accuracy: 0.9263
# Epoch 26/30
# 140/140 [==============================] - 46s 329ms/step - loss: 0.2661 - accuracy: 0.9267 - val_loss: 0.2927 - val_accuracy: 0.9151
# Epoch 27/30
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2724 - accuracy: 0.9239 - val_loss: 0.2446 - val_accuracy: 0.9297
# Epoch 28/30
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2653 - accuracy: 0.9261 - val_loss: 0.2796 - val_accuracy: 0.9159
# Epoch 29/30
# 140/140 [==============================] - 46s 327ms/step - loss: 0.2703 - accuracy: 0.9264 - val_loss: 0.2686 - val_accuracy: 0.9300
# Epoch 30/30
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2661 - accuracy: 0.9273 - val_loss: 0.2649 - val_accuracy: 0.9248
# Wall time: 1403.58 seconds

# %%
# visualize accuracy and loss history
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].legend(['Train', 'Val'])

axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# #### Model results

# %%
# save model to S3
s3_save_keras_model(model, f'{model_id}-{data_id}{note}')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpj4k0t950/yuclassify-paper-thin2/assets

# %%
# compute model results on test set
start = time.time()
results = model.evaluate(x_test, y_test)
print("Wall time: {:.2f} seconds".format(time.time() - start))
print(results)
# Out:
# 120/120 [==============================] - 3s 23ms/step - loss: 0.2616 - accuracy: 0.9297
# Wall time: 3.22 seconds
# [0.2616112232208252, 0.9297283291816711]

# %%
# generate predictions for model analysis
start = time.time()
y_pred = model.predict(x_test)
y_max = np.argmax(y_pred, axis=1).astype(np.uint8)
predictions = [y_max, y_pred]
print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Wall time: 2.39 seconds

# %%
# save predictions to local instance
with open(f'{result_path}/{model_id}-{data_id}{note}.pkl', "wb") as f:
    pickle.dump(predictions, f)

# %%
# plot confusion matrix
helper.plot_confusion_matrix(y_test, y_max, mode='classify', normalize=True)

# %%
# plot confusion matrix counts
helper.plot_confusion_matrix(y_test, y_max, mode='classify', normalize=False)
