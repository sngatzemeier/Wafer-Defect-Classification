# %% [markdown]
# #### Classify model from Yu, et al
# Implementation of the classification model from the Yu, et al [paper](https://drive.google.com/file/d/1nYl4w41CAcj8XwTEdVwcD5lVheUFIHVy/view?usp=sharing)

# %%
# !pip install pickle5
# Out:
# Requirement already satisfied: pickle5 in /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages (0.0.12)

# %%
# import libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, optimizers, regularizers, callbacks

import os
import time
import numpy as np
import pandas as pd

import helpers as helper
from keras_model_s3_wrapper import *

import boto3
import pickle5 as pickle
s3 = boto3.resource('s3')
bucket_name = 'wafer-capstone'
my_bucket = s3.Bucket(bucket_name)

# %%
tf.__version__
# Out:
# '2.3.4'

# %%
tf.config.list_physical_devices(device_type=None)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# specify variables for model
path = 'processed_data/WM-clean-paper'
result_path = 'results'
model_path = '../saved_models'

filename = 'WM-clean-paper'
option = '-classify' # -classify, -knn
map_column = 'waferMap224'

model_id = 'yuclassify'
data_id = 'paper'
note = '' # -optional

# %%
# load train, dev, and test sets
# directly from S3 (using boto3 resource)
start = time.time()

train_key = f'{path}/{filename}-train{option}.pkl'
dev_key = f'{path}/{filename}-dev.pkl'
test_key = f'{path}/{filename}-test.pkl'

train = pickle.loads(my_bucket.Object(train_key).get()['Body'].read())
dev = pickle.loads(my_bucket.Object(dev_key).get()['Body'].read())
test = pickle.loads(my_bucket.Object(test_key).get()['Body'].read())

# remove nones from dev and test

dev = dev[dev.classifyLabels != 8].reset_index(drop=True)
test = test[test.classifyLabels != 8].reset_index(drop=True)

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(train[map_column][0])}")
# Out:
# Wall time: 39.93 seconds
# Train: 17863
# Dev: 3828
# Test: 3828
# Sanity check: [0 1 2]

# %% [markdown]
# #### Quick EDA

# %%
# train failure type distribution
helper.defect_distribution(train, note='Train Set')

# %%
# dev failure type distribution
helper.defect_distribution(dev, note='Dev Set')

# %%
# test failure type distribution
helper.defect_distribution(test, note='Test Set')

# %% [markdown]
# #### Data set-up

# %%
# prepare inputs
start = time.time()

x_train = np.stack(train[map_column])
x_val = np.stack(dev[map_column])
x_test = np.stack(test[map_column])

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: (#rows, xdim, ydim)
print(x_train.shape)
# Out:
# Wall time: 0.41 seconds
# (17863, 224, 224)

# %%
# expand tensor and create dummy dimension at axis 3
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.expand_dims(x_train, axis=3, name=None)
x_val = tf.expand_dims(x_val, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 1])
x_train.shape
# Out:
# Wall time: 1.99 seconds
# TensorShape([17863, 224, 224, 1])

# %%
# prepare labels for supervised learning
# note: make sure labels are integers if using sparse categorical cross entropy
start = time.time()

y_train = np.asarray(train['classifyLabels']).astype(np.uint8)
y_val = np.asarray(dev['classifyLabels']).astype(np.uint8)
y_test = np.asarray(test['classifyLabels']).astype(np.uint8)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: type = int, min = 0, max = 7
print(type(y_train[0]))
print(min(y_train), min(y_val), min(y_test))
print(max(y_train), max(y_val), max(y_test))
# Out:
# Wall time: 0.00 seconds
# <class 'numpy.uint8'>
# 0 0 0
# 7 7 7

# %% [markdown]
# #### Model

# %%
# define model architecture

model = models.Sequential()
model.add(layers.experimental.preprocessing.Rescaling(scale=1./2., input_shape=x_train.shape[1:]))
model.add(layers.experimental.preprocessing.RandomFlip(seed=424))
model.add(layers.experimental.preprocessing.RandomRotation(1, fill_mode='constant', interpolation='nearest', seed=424))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu', input_shape=x_train.shape[1:]))
model.add(layers.Conv2D(32, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(64, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.Conv2D(128, 3, padding='same', activation='relu'))
model.add(layers.MaxPooling2D(3))
model.add(layers.Flatten())
model.add(layers.Dense(4096, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dense(1024, activation='sigmoid', kernel_regularizer=regularizers.l2(0.000001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(8, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 224, 224, 1)       0
# _________________________________________________________________
# random_flip (RandomFlip)     (None, 224, 224, 1)       0
# _________________________________________________________________
# random_rotation (RandomRotat (None, 224, 224, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 74, 74, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 74, 74, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 8200
# =================================================================
# Total params: 38,196,072
# Trainable params: 38,196,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set model optimizer and metrics
opt = optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer='adam', loss=losses.sparse_categorical_crossentropy, metrics=['accuracy'])

# %%
# run model
start = time.time()

history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=128, epochs=80)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Epoch 1/80
#   2/140 [..............................] - ETA: 22s - loss: 5.1471 - accuracy: 0.2539WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0844s vs `on_train_batch_end` time: 0.2277s). Check your callbacks.
# 140/140 [==============================] - 48s 346ms/step - loss: 1.4993 - accuracy: 0.5126 - val_loss: 0.7351 - val_accuracy: 0.7335
# Epoch 2/80
# 140/140 [==============================] - 47s 339ms/step - loss: 0.5374 - accuracy: 0.8045 - val_loss: 0.4030 - val_accuracy: 0.8508
# Epoch 3/80
# 140/140 [==============================] - 47s 336ms/step - loss: 0.4012 - accuracy: 0.8523 - val_loss: 0.3498 - val_accuracy: 0.8801
# Epoch 4/80
# 140/140 [==============================] - 47s 335ms/step - loss: 0.3284 - accuracy: 0.8784 - val_loss: 0.3004 - val_accuracy: 0.8918
# Epoch 5/80
# 140/140 [==============================] - 46s 331ms/step - loss: 0.3045 - accuracy: 0.8879 - val_loss: 0.2791 - val_accuracy: 0.9060
# Epoch 6/80
# 140/140 [==============================] - 44s 317ms/step - loss: 0.2913 - accuracy: 0.8950 - val_loss: 0.2456 - val_accuracy: 0.9127
# Epoch 7/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2585 - accuracy: 0.9110 - val_loss: 0.2879 - val_accuracy: 0.8999
# Epoch 8/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2557 - accuracy: 0.9113 - val_loss: 0.2331 - val_accuracy: 0.9198
# Epoch 9/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2461 - accuracy: 0.9174 - val_loss: 0.2189 - val_accuracy: 0.9271
# Epoch 10/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2387 - accuracy: 0.9174 - val_loss: 0.2593 - val_accuracy: 0.9161
# Epoch 11/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2294 - accuracy: 0.9205 - val_loss: 0.2118 - val_accuracy: 0.9303
# Epoch 12/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2345 - accuracy: 0.9215 - val_loss: 0.2101 - val_accuracy: 0.9297
# Epoch 13/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2245 - accuracy: 0.9250 - val_loss: 0.2400 - val_accuracy: 0.9232
# Epoch 14/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2283 - accuracy: 0.9252 - val_loss: 0.2515 - val_accuracy: 0.9193
# Epoch 15/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2249 - accuracy: 0.9243 - val_loss: 0.2210 - val_accuracy: 0.9271
# Epoch 16/80
# 140/140 [==============================] - 44s 317ms/step - loss: 0.2254 - accuracy: 0.9260 - val_loss: 0.2069 - val_accuracy: 0.9394
# Epoch 17/80
# 140/140 [==============================] - 45s 319ms/step - loss: 0.2218 - accuracy: 0.9269 - val_loss: 0.2251 - val_accuracy: 0.9242
# Epoch 18/80
# 140/140 [==============================] - 45s 324ms/step - loss: 0.2155 - accuracy: 0.9325 - val_loss: 0.1987 - val_accuracy: 0.9355
# Epoch 19/80
# 140/140 [==============================] - 45s 318ms/step - loss: 0.2254 - accuracy: 0.9282 - val_loss: 0.2172 - val_accuracy: 0.9282
# Epoch 20/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2212 - accuracy: 0.9312 - val_loss: 0.2080 - val_accuracy: 0.9342
# Epoch 21/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2192 - accuracy: 0.9306 - val_loss: 0.2141 - val_accuracy: 0.9342
# Epoch 22/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2117 - accuracy: 0.9342 - val_loss: 0.2279 - val_accuracy: 0.9289
# Epoch 23/80
# 140/140 [==============================] - 44s 317ms/step - loss: 0.2116 - accuracy: 0.9342 - val_loss: 0.2252 - val_accuracy: 0.9352
# Epoch 24/80
# 140/140 [==============================] - 45s 320ms/step - loss: 0.2210 - accuracy: 0.9309 - val_loss: 0.2177 - val_accuracy: 0.9297
# Epoch 25/80
# 140/140 [==============================] - 45s 324ms/step - loss: 0.2170 - accuracy: 0.9324 - val_loss: 0.2052 - val_accuracy: 0.9321
# Epoch 26/80
# 140/140 [==============================] - 44s 316ms/step - loss: 0.2153 - accuracy: 0.9338 - val_loss: 0.2235 - val_accuracy: 0.9363
# Epoch 27/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2117 - accuracy: 0.9360 - val_loss: 0.2077 - val_accuracy: 0.9391
# Epoch 28/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2159 - accuracy: 0.9341 - val_loss: 0.2465 - val_accuracy: 0.9235
# Epoch 29/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2178 - accuracy: 0.9361 - val_loss: 0.2187 - val_accuracy: 0.9342
# Epoch 30/80
# 140/140 [==============================] - 44s 317ms/step - loss: 0.2144 - accuracy: 0.9371 - val_loss: 0.2010 - val_accuracy: 0.9407
# Epoch 31/80
# 140/140 [==============================] - 45s 320ms/step - loss: 0.2116 - accuracy: 0.9377 - val_loss: 0.2079 - val_accuracy: 0.9394
# Epoch 32/80
# 140/140 [==============================] - 46s 327ms/step - loss: 0.2103 - accuracy: 0.9401 - val_loss: 0.1988 - val_accuracy: 0.9402
# Epoch 33/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2058 - accuracy: 0.9411 - val_loss: 0.2123 - val_accuracy: 0.9397
# Epoch 34/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2120 - accuracy: 0.9386 - val_loss: 0.2038 - val_accuracy: 0.9444
# Epoch 35/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2152 - accuracy: 0.9394 - val_loss: 0.2239 - val_accuracy: 0.9355
# Epoch 36/80
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2116 - accuracy: 0.9411 - val_loss: 0.2071 - val_accuracy: 0.9425
# Epoch 37/80
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2162 - accuracy: 0.9374 - val_loss: 0.2050 - val_accuracy: 0.9399
# Epoch 38/80
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2200 - accuracy: 0.9377 - val_loss: 0.2087 - val_accuracy: 0.9381
# Epoch 39/80
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2189 - accuracy: 0.9394 - val_loss: 0.2148 - val_accuracy: 0.9386
# Epoch 40/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2120 - accuracy: 0.9420 - val_loss: 0.2176 - val_accuracy: 0.9389
# Epoch 41/80
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2175 - accuracy: 0.9407 - val_loss: 0.2104 - val_accuracy: 0.9425
# Epoch 42/80
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2182 - accuracy: 0.9397 - val_loss: 0.2205 - val_accuracy: 0.9386
# Epoch 43/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2130 - accuracy: 0.9427 - val_loss: 0.2264 - val_accuracy: 0.9415
# Epoch 44/80
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2172 - accuracy: 0.9420 - val_loss: 0.2269 - val_accuracy: 0.9381
# Epoch 45/80
# 140/140 [==============================] - 45s 324ms/step - loss: 0.2195 - accuracy: 0.9415 - val_loss: 0.2422 - val_accuracy: 0.9295
# Epoch 46/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2147 - accuracy: 0.9438 - val_loss: 0.2274 - val_accuracy: 0.9389
# Epoch 47/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2172 - accuracy: 0.9403 - val_loss: 0.2133 - val_accuracy: 0.9433
# Epoch 48/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2194 - accuracy: 0.9411 - val_loss: 0.2205 - val_accuracy: 0.9410
# Epoch 49/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2211 - accuracy: 0.9406 - val_loss: 0.2267 - val_accuracy: 0.9368
# Epoch 50/80
# 140/140 [==============================] - 45s 319ms/step - loss: 0.2189 - accuracy: 0.9416 - val_loss: 0.2246 - val_accuracy: 0.9360
# Epoch 51/80
# 140/140 [==============================] - 45s 322ms/step - loss: 0.2171 - accuracy: 0.9426 - val_loss: 0.2239 - val_accuracy: 0.9436
# Epoch 52/80
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2223 - accuracy: 0.9413 - val_loss: 0.2272 - val_accuracy: 0.9433
# Epoch 53/80
# 140/140 [==============================] - 47s 335ms/step - loss: 0.2211 - accuracy: 0.9435 - val_loss: 0.2248 - val_accuracy: 0.9399
# Epoch 54/80
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2214 - accuracy: 0.9422 - val_loss: 0.2321 - val_accuracy: 0.9410
# Epoch 55/80
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2198 - accuracy: 0.9445 - val_loss: 0.2372 - val_accuracy: 0.9376
# Epoch 56/80
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2204 - accuracy: 0.9430 - val_loss: 0.2249 - val_accuracy: 0.9436
# Epoch 57/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2177 - accuracy: 0.9439 - val_loss: 0.2343 - val_accuracy: 0.9423
# Epoch 58/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2173 - accuracy: 0.9449 - val_loss: 0.2214 - val_accuracy: 0.9441
# Epoch 59/80
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2214 - accuracy: 0.9435 - val_loss: 0.2405 - val_accuracy: 0.9365
# Epoch 60/80
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2236 - accuracy: 0.9432 - val_loss: 0.2468 - val_accuracy: 0.9368
# Epoch 61/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2288 - accuracy: 0.9410 - val_loss: 0.2456 - val_accuracy: 0.9391
# Epoch 62/80
# 140/140 [==============================] - 46s 330ms/step - loss: 0.2240 - accuracy: 0.9433 - val_loss: 0.2288 - val_accuracy: 0.9415
# Epoch 63/80
# 140/140 [==============================] - 47s 332ms/step - loss: 0.2244 - accuracy: 0.9449 - val_loss: 0.2293 - val_accuracy: 0.9417
# Epoch 64/80
# 140/140 [==============================] - 47s 333ms/step - loss: 0.2257 - accuracy: 0.9426 - val_loss: 0.2460 - val_accuracy: 0.9373
# Epoch 65/80
# 140/140 [==============================] - 44s 318ms/step - loss: 0.2240 - accuracy: 0.9442 - val_loss: 0.2396 - val_accuracy: 0.9423
# Epoch 66/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2212 - accuracy: 0.9463 - val_loss: 0.2244 - val_accuracy: 0.9454
# Epoch 67/80
# 140/140 [==============================] - 44s 313ms/step - loss: 0.2264 - accuracy: 0.9460 - val_loss: 0.2419 - val_accuracy: 0.9402
# Epoch 68/80
# 140/140 [==============================] - 44s 314ms/step - loss: 0.2264 - accuracy: 0.9435 - val_loss: 0.2397 - val_accuracy: 0.9431
# Epoch 69/80
# 140/140 [==============================] - 44s 315ms/step - loss: 0.2259 - accuracy: 0.9447 - val_loss: 0.2364 - val_accuracy: 0.9412
# Epoch 70/80
# 140/140 [==============================] - 45s 319ms/step - loss: 0.2231 - accuracy: 0.9470 - val_loss: 0.2286 - val_accuracy: 0.9457
# Epoch 71/80
# 140/140 [==============================] - 45s 324ms/step - loss: 0.2241 - accuracy: 0.9453 - val_loss: 0.2370 - val_accuracy: 0.9407
# Epoch 72/80
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2223 - accuracy: 0.9456 - val_loss: 0.2429 - val_accuracy: 0.9404
# Epoch 73/80
# 140/140 [==============================] - 47s 334ms/step - loss: 0.2244 - accuracy: 0.9469 - val_loss: 0.2462 - val_accuracy: 0.9397
# Epoch 74/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2347 - accuracy: 0.9420 - val_loss: 0.2402 - val_accuracy: 0.9425
# Epoch 75/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2305 - accuracy: 0.9451 - val_loss: 0.2507 - val_accuracy: 0.9368
# Epoch 76/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2300 - accuracy: 0.9446 - val_loss: 0.2477 - val_accuracy: 0.9365
# Epoch 77/80
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2298 - accuracy: 0.9448 - val_loss: 0.2306 - val_accuracy: 0.9467
# Epoch 78/80
# 140/140 [==============================] - 46s 331ms/step - loss: 0.2304 - accuracy: 0.9437 - val_loss: 0.2429 - val_accuracy: 0.9457
# Epoch 79/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2350 - accuracy: 0.9439 - val_loss: 0.2314 - val_accuracy: 0.9470
# Epoch 80/80
# 140/140 [==============================] - 46s 332ms/step - loss: 0.2310 - accuracy: 0.9455 - val_loss: 0.2596 - val_accuracy: 0.9336
# Wall time: 3648.85 seconds

# %%
# visualize accuracy and loss history
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].legend(['Train', 'Val'])

axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# #### Model results

# %%
# save model to local instance
model.save(f'{model_path}/{model_id}-{data_id}{note}')
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../saved_models/yuclassify-paper/assets

# %%
# save model to S3
s3_save_keras_model(model, f'{model_id}-{data_id}{note}')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpszvu05md/yuclassify-paper/assets

# %%
# compute model results on test set
start = time.time()
results = model.evaluate(x_test, y_test)
print("Wall time: {:.2f} seconds".format(time.time() - start))
print(results)
# Out:
# 120/120 [==============================] - 3s 23ms/step - loss: 0.2579 - accuracy: 0.9376
# Wall time: 3.20 seconds
# [0.25785335898399353, 0.9375653266906738]

# %%
# generate predictions for model analysis
start = time.time()
y_pred = model.predict(x_test)
y_max = np.argmax(y_pred, axis=1).astype(np.uint8)
predictions = [y_max, y_pred]
print("Wall time: {:.2f} seconds".format(time.time() - start))
# Out:
# Wall time: 2.57 seconds

# %%
# save predictions to local instance
with open(f'{result_path}/{model_id}-{data_id}{note}.pkl', "wb") as f:
    pickle.dump(predictions, f)

# %%
# plot confusion matrix
helper.plot_confusion_matrix(y_test, y_max, mode='classify', normalize=True)

# %%
# plot confusion matrix counts
helper.plot_confusion_matrix(y_test, y_max, mode='classify', normalize=False)
