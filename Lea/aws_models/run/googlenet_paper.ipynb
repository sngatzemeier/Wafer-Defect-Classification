# %% [markdown]
# #### Using GoogLeNet as Classify Model
# Following GoogLeNet implementation from this [blog](https://ai.plainenglish.io/googlenet-inceptionv1-with-tensorflow-9e7f3a161e87)
#
# Use GoogLeNet to classify defect patterns only (i.e., as an alternative to Yu classify model).  Data preprocessed the same as Yu paper.

# %%
# !pip install pickle5

# %%
# import libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, optimizers, callbacks, Model

import os
import time
import numpy as np
import pandas as pd

import helpers as helper
from keras_model_s3_wrapper import *

import boto3
import pickle5 as pickle
s3 = boto3.resource('s3')
bucket_name = 'wafer-capstone'
my_bucket = s3.Bucket(bucket_name)

# %%
tf.__version__
# Out:
# '2.3.4'

# %%
tf.config.list_physical_devices(device_type=None)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# specify variables for model
path = 'processed_data/WM-clean-paper'
result_path = 'results'
model_path = '../saved_models'

filename = 'WM-clean-paper'
option = '-classify' # -classify, -knn
map_column = 'waferMap224'

model_id = 'googlenet'
data_id = 'paper'
note = '' # -optional

x = 224
y = 224

# %%
# load train, dev, and test sets
# directly from S3 (using boto3 resource)
start = time.time()

train_key = f'{path}/{filename}-train{option}.pkl'
dev_key = f'{path}/{filename}-dev.pkl'
test_key = f'{path}/{filename}-test.pkl'

train = pickle.loads(my_bucket.Object(train_key).get()['Body'].read())
dev = pickle.loads(my_bucket.Object(dev_key).get()['Body'].read())
test = pickle.loads(my_bucket.Object(test_key).get()['Body'].read())

# remove nones from dev and test

dev = dev[dev.classifyLabels != 8].reset_index(drop=True)
test = test[test.classifyLabels != 8].reset_index(drop=True)

print("Wall time: {:.2f} seconds".format(time.time() - start))
print(f"Train: {len(train)}")
print(f"Dev: {len(dev)}")
print(f"Test: {len(test)}")

print(f"Sanity check: {np.unique(train[map_column][0])}")
# Out:
# Wall time: 40.71 seconds
# Train: 17863
# Dev: 3828
# Test: 3828
# Sanity check: [0 1 2]

# %% [markdown]
# #### Quick EDA

# %%
# train failure type distribution
helper.defect_distribution(train, note='Train Set')

# %%
# dev failure type distribution
helper.defect_distribution(dev, note='Dev Set')

# %%
# test failure type distribution
helper.defect_distribution(test, note='Test Set')

# %% [markdown]
# #### Data set-up

# %%
# prepare inputs
start = time.time()

x_train = np.stack(train[map_column])
x_val = np.stack(dev[map_column])
x_test = np.stack(test[map_column])

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: (#rows, xdim, ydim)
print(x_train.shape)
# Out:
# Wall time: 0.41 seconds
# (17863, 224, 224)

# %%
# expand tensor and repeat 3 times
# images in greyscale, so no channel dimension
start = time.time()

x_train = tf.expand_dims(x_train, axis=3, name=None)
x_val = tf.expand_dims(x_val, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)

x_train = tf.repeat(x_train, 3, axis=3)
x_val = tf.repeat(x_val, 3, axis=3)
x_test = tf.repeat(x_test, 3, axis=3)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: TensorShape([#rows, xdim, ydim, 3])
x_train.shape
# Out:
# Wall time: 4.52 seconds
# TensorShape([17863, 224, 224, 3])

# %%
# prepare labels for supervised learning
# note: make sure labels are integers if using sparse categorical cross entropy
start = time.time()

y_train = np.asarray(train['classifyLabels']).astype(np.uint8)
y_val = np.asarray(dev['classifyLabels']).astype(np.uint8)
y_test = np.asarray(test['classifyLabels']).astype(np.uint8)

print("Wall time: {:.2f} seconds".format(time.time() - start))
# sanity check
# expected: type = int, min = 0, max = 7
print(type(y_train[0]))
print(min(y_train), min(y_val), min(y_test))
print(max(y_train), max(y_val), max(y_test))
# Out:
# Wall time: 0.00 seconds
# <class 'numpy.uint8'>
# 0 0 0
# 7 7 7

# %% [markdown]
# #### Model

# %%
def inception(x,
              filters_1x1,
              filters_3x3_reduce,
              filters_3x3,
              filters_5x5_reduce,
              filters_5x5,
              filters_pool):
  path1 = layers.Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

  path2 = layers.Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
  path2 = layers.Conv2D(filters_3x3, (1, 1), padding='same', activation='relu')(path2)

  path3 = layers.Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
  path3 = layers.Conv2D(filters_5x5, (1, 1), padding='same', activation='relu')(path3)

  path4 = layers.MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
  path4 = layers.Conv2D(filters_pool, (1, 1), padding='same', activation='relu')(path4)

  return tf.concat([path1, path2, path3, path4], axis=3)

# %%
inp = layers.Input(shape=(x, y, 3))
input_tensor = layers.experimental.preprocessing.Rescaling(scale=1./2.)(inp)

x = layers.Conv2D(64, 7, strides=2, padding='same', activation='relu')(input_tensor)
x = layers.MaxPooling2D(3, strides=2)(x)

x = layers.Conv2D(64, 1, strides=1, padding='same', activation='relu')(x)
x = layers.Conv2D(192, 3, strides=1, padding='same', activation='relu')(x)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=64,
              filters_3x3_reduce=96,
              filters_3x3=128,
              filters_5x5_reduce=16,
              filters_5x5=32,
              filters_pool=32)

x = inception(x,
              filters_1x1=128,
              filters_3x3_reduce=128,
              filters_3x3=192,
              filters_5x5_reduce=32,
              filters_5x5=96,
              filters_pool=64)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=192,
              filters_3x3_reduce=96,
              filters_3x3=208,
              filters_5x5_reduce=16,
              filters_5x5=48,
              filters_pool=64)

aux1 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux1 = layers.Conv2D(128, 1, padding='same', activation='relu')(aux1)
aux1 = layers.Flatten()(aux1)
aux1 = layers.Dense(1024, activation='relu')(aux1)
aux1 = layers.Dropout(0.7)(aux1)
aux1 = layers.Dense(10, activation='softmax')(aux1)

x = inception(x,
              filters_1x1=160,
              filters_3x3_reduce=112,
              filters_3x3=224,
              filters_5x5_reduce=24,
              filters_5x5=64,
              filters_pool=64)

x = inception(x,
              filters_1x1=128,
              filters_3x3_reduce=128,
              filters_3x3=256,
              filters_5x5_reduce=24,
              filters_5x5=64,
              filters_pool=64)

x = inception(x,
              filters_1x1=112,
              filters_3x3_reduce=144,
              filters_3x3=288,
              filters_5x5_reduce=32,
              filters_5x5=64,
              filters_pool=64)

aux2 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux2 = layers.Conv2D(128, 1, padding='same', activation='relu')(aux2)
aux2 = layers.Flatten()(aux2)
aux2 = layers.Dense(1024, activation='relu')(aux2)
aux2 = layers.Dropout(0.7)(aux2)
aux2 = layers.Dense(10, activation='softmax')(aux2)

x = inception(x,
              filters_1x1=256,
              filters_3x3_reduce=160,
              filters_3x3=320,
              filters_5x5_reduce=32,
              filters_5x5=128,
              filters_pool=128)

x = layers.MaxPooling2D(3, strides=2)(x)

x = inception(x,
              filters_1x1=256,
              filters_3x3_reduce=160,
              filters_3x3=320,
              filters_5x5_reduce=32,
              filters_5x5=128,
              filters_pool=128)

x = inception(x,
              filters_1x1=384,
              filters_3x3_reduce=192,
              filters_3x3=384,
              filters_5x5_reduce=48,
              filters_5x5=128,
              filters_pool=128)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dropout(0.4)(x)
out = layers.Dense(9, activation='softmax')(x)

# %%
model = Model(inputs = inp, outputs = [out, aux1, aux2])

# %%
model.compile(optimizer='adam', loss=[losses.sparse_categorical_crossentropy, losses.sparse_categorical_crossentropy, losses.sparse_categorical_crossentropy], loss_weights=[1, 0.3, 0.3], metrics=['accuracy'])

# %%
history = model.fit(x_train, [y_train, y_train, y_train], validation_data=(x_val, [y_val, y_val, y_val]), batch_size=64, epochs=30)
# Out:
# Epoch 1/30
#   2/280 [..............................] - ETA: 20s - loss: 3.5167 - dense_4_loss: 2.1634 - dense_1_loss: 2.2536 - dense_3_loss: 2.2573 - dense_4_accuracy: 0.2344 - dense_1_accuracy: 0.2031 - dense_3_accuracy: 0.2656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0539s vs `on_train_batch_end` time: 0.0904s). Check your callbacks.
# 280/280 [==============================] - 45s 162ms/step - loss: 1.9701 - dense_4_loss: 1.2268 - dense_1_loss: 1.2477 - dense_3_loss: 1.2297 - dense_4_accuracy: 0.5277 - dense_1_accuracy: 0.5261 - dense_3_accuracy: 0.5322 - val_loss: 1.6140 - val_dense_4_loss: 1.0186 - val_dense_1_loss: 0.9864 - val_dense_3_loss: 0.9982 - val_dense_4_accuracy: 0.6424 - val_dense_1_accuracy: 0.6374 - val_dense_3_accuracy: 0.6776
# Epoch 2/30
# 280/280 [==============================] - 43s 154ms/step - loss: 1.2014 - dense_4_loss: 0.7331 - dense_1_loss: 0.7979 - dense_3_loss: 0.7632 - dense_4_accuracy: 0.7209 - dense_1_accuracy: 0.6939 - dense_3_accuracy: 0.7093 - val_loss: 1.0767 - val_dense_4_loss: 0.6645 - val_dense_1_loss: 0.6872 - val_dense_3_loss: 0.6867 - val_dense_4_accuracy: 0.7377 - val_dense_1_accuracy: 0.7330 - val_dense_3_accuracy: 0.7176
# Epoch 3/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.8970 - dense_4_loss: 0.5416 - dense_1_loss: 0.6170 - dense_3_loss: 0.5676 - dense_4_accuracy: 0.7933 - dense_1_accuracy: 0.7679 - dense_3_accuracy: 0.7877 - val_loss: 0.7966 - val_dense_4_loss: 0.4985 - val_dense_1_loss: 0.5154 - val_dense_3_loss: 0.4782 - val_dense_4_accuracy: 0.8169 - val_dense_1_accuracy: 0.8064 - val_dense_3_accuracy: 0.8284
# Epoch 4/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.7574 - dense_4_loss: 0.4549 - dense_1_loss: 0.5340 - dense_3_loss: 0.4746 - dense_4_accuracy: 0.8301 - dense_1_accuracy: 0.7992 - dense_3_accuracy: 0.8266 - val_loss: 0.6703 - val_dense_4_loss: 0.4080 - val_dense_1_loss: 0.4670 - val_dense_3_loss: 0.4073 - val_dense_4_accuracy: 0.8427 - val_dense_1_accuracy: 0.8281 - val_dense_3_accuracy: 0.8433
# Epoch 5/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.6256 - dense_4_loss: 0.3661 - dense_1_loss: 0.4689 - dense_3_loss: 0.3959 - dense_4_accuracy: 0.8675 - dense_1_accuracy: 0.8254 - dense_3_accuracy: 0.8552 - val_loss: 0.5171 - val_dense_4_loss: 0.2961 - val_dense_1_loss: 0.4116 - val_dense_3_loss: 0.3250 - val_dense_4_accuracy: 0.8830 - val_dense_1_accuracy: 0.8425 - val_dense_3_accuracy: 0.8686
# Epoch 6/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.5567 - dense_4_loss: 0.3237 - dense_1_loss: 0.4237 - dense_3_loss: 0.3529 - dense_4_accuracy: 0.8826 - dense_1_accuracy: 0.8414 - dense_3_accuracy: 0.8700 - val_loss: 0.5446 - val_dense_4_loss: 0.3355 - val_dense_1_loss: 0.3508 - val_dense_3_loss: 0.3461 - val_dense_4_accuracy: 0.8694 - val_dense_1_accuracy: 0.8723 - val_dense_3_accuracy: 0.8681
# Epoch 7/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.5143 - dense_4_loss: 0.2985 - dense_1_loss: 0.3961 - dense_3_loss: 0.3231 - dense_4_accuracy: 0.8911 - dense_1_accuracy: 0.8515 - dense_3_accuracy: 0.8828 - val_loss: 0.5142 - val_dense_4_loss: 0.3190 - val_dense_1_loss: 0.3370 - val_dense_3_loss: 0.3137 - val_dense_4_accuracy: 0.8707 - val_dense_1_accuracy: 0.8717 - val_dense_3_accuracy: 0.8770
# Epoch 8/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.4887 - dense_4_loss: 0.2837 - dense_1_loss: 0.3767 - dense_3_loss: 0.3067 - dense_4_accuracy: 0.8979 - dense_1_accuracy: 0.8600 - dense_3_accuracy: 0.8898 - val_loss: 0.5665 - val_dense_4_loss: 0.3524 - val_dense_1_loss: 0.3846 - val_dense_3_loss: 0.3291 - val_dense_4_accuracy: 0.8676 - val_dense_1_accuracy: 0.8485 - val_dense_3_accuracy: 0.8689
# Epoch 9/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.4558 - dense_4_loss: 0.2646 - dense_1_loss: 0.3460 - dense_3_loss: 0.2915 - dense_4_accuracy: 0.9041 - dense_1_accuracy: 0.8738 - dense_3_accuracy: 0.8965 - val_loss: 0.4008 - val_dense_4_loss: 0.2425 - val_dense_1_loss: 0.2853 - val_dense_3_loss: 0.2422 - val_dense_4_accuracy: 0.9078 - val_dense_1_accuracy: 0.8979 - val_dense_3_accuracy: 0.9086
# Epoch 10/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.4235 - dense_4_loss: 0.2468 - dense_1_loss: 0.3242 - dense_3_loss: 0.2646 - dense_4_accuracy: 0.9110 - dense_1_accuracy: 0.8828 - dense_3_accuracy: 0.9045 - val_loss: 0.4227 - val_dense_4_loss: 0.2560 - val_dense_1_loss: 0.2780 - val_dense_3_loss: 0.2777 - val_dense_4_accuracy: 0.8976 - val_dense_1_accuracy: 0.8934 - val_dense_3_accuracy: 0.8934
# Epoch 11/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.4138 - dense_4_loss: 0.2390 - dense_1_loss: 0.3218 - dense_3_loss: 0.2608 - dense_4_accuracy: 0.9132 - dense_1_accuracy: 0.8827 - dense_3_accuracy: 0.9070 - val_loss: 0.5467 - val_dense_4_loss: 0.3408 - val_dense_1_loss: 0.3198 - val_dense_3_loss: 0.3664 - val_dense_4_accuracy: 0.8720 - val_dense_1_accuracy: 0.8783 - val_dense_3_accuracy: 0.8681
# Epoch 12/30
# 280/280 [==============================] - 43s 154ms/step - loss: 0.3885 - dense_4_loss: 0.2258 - dense_1_loss: 0.2947 - dense_3_loss: 0.2476 - dense_4_accuracy: 0.9178 - dense_1_accuracy: 0.8919 - dense_3_accuracy: 0.9101 - val_loss: 0.4730 - val_dense_4_loss: 0.3007 - val_dense_1_loss: 0.3018 - val_dense_3_loss: 0.2724 - val_dense_4_accuracy: 0.8966 - val_dense_1_accuracy: 0.8942 - val_dense_3_accuracy: 0.8994
# Epoch 13/30
# 280/280 [==============================] - 43s 155ms/step - loss: 0.3556 - dense_4_loss: 0.2048 - dense_1_loss: 0.2783 - dense_3_loss: 0.2243 - dense_4_accuracy: 0.9264 - dense_1_accuracy: 0.9014 - dense_3_accuracy: 0.9218 - val_loss: 0.4231 - val_dense_4_loss: 0.2607 - val_dense_1_loss: 0.2785 - val_dense_3_loss: 0.2627 - val_dense_4_accuracy: 0.9086 - val_dense_1_accuracy: 0.8971 - val_dense_3_accuracy: 0.9033
# Epoch 14/30
# 280/280 [==============================] - 44s 157ms/step - loss: 0.3520 - dense_4_loss: 0.2051 - dense_1_loss: 0.2667 - dense_3_loss: 0.2232 - dense_4_accuracy: 0.9253 - dense_1_accuracy: 0.9038 - dense_3_accuracy: 0.9206 - val_loss: 0.4579 - val_dense_4_loss: 0.3050 - val_dense_1_loss: 0.2454 - val_dense_3_loss: 0.2642 - val_dense_4_accuracy: 0.9013 - val_dense_1_accuracy: 0.9125 - val_dense_3_accuracy: 0.9117
# Epoch 15/30
# 280/280 [==============================] - 44s 156ms/step - loss: 0.3388 - dense_4_loss: 0.1974 - dense_1_loss: 0.2604 - dense_3_loss: 0.2111 - dense_4_accuracy: 0.9285 - dense_1_accuracy: 0.9060 - dense_3_accuracy: 0.9230 - val_loss: 0.4559 - val_dense_4_loss: 0.2928 - val_dense_1_loss: 0.2576 - val_dense_3_loss: 0.2861 - val_dense_4_accuracy: 0.9039 - val_dense_1_accuracy: 0.8997 - val_dense_3_accuracy: 0.8992
# Epoch 16/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.3123 - dense_4_loss: 0.1801 - dense_1_loss: 0.2439 - dense_3_loss: 0.1967 - dense_4_accuracy: 0.9338 - dense_1_accuracy: 0.9086 - dense_3_accuracy: 0.9289 - val_loss: 0.4459 - val_dense_4_loss: 0.2806 - val_dense_1_loss: 0.2815 - val_dense_3_loss: 0.2696 - val_dense_4_accuracy: 0.8864 - val_dense_1_accuracy: 0.8999 - val_dense_3_accuracy: 0.8911
# Epoch 17/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.2921 - dense_4_loss: 0.1687 - dense_1_loss: 0.2285 - dense_3_loss: 0.1828 - dense_4_accuracy: 0.9393 - dense_1_accuracy: 0.9189 - dense_3_accuracy: 0.9334 - val_loss: 0.4018 - val_dense_4_loss: 0.2429 - val_dense_1_loss: 0.2685 - val_dense_3_loss: 0.2611 - val_dense_4_accuracy: 0.9112 - val_dense_1_accuracy: 0.9073 - val_dense_3_accuracy: 0.9046
# Epoch 18/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.2933 - dense_4_loss: 0.1694 - dense_1_loss: 0.2289 - dense_3_loss: 0.1840 - dense_4_accuracy: 0.9381 - dense_1_accuracy: 0.9177 - dense_3_accuracy: 0.9343 - val_loss: 0.4537 - val_dense_4_loss: 0.2735 - val_dense_1_loss: 0.2928 - val_dense_3_loss: 0.3079 - val_dense_4_accuracy: 0.9057 - val_dense_1_accuracy: 0.8997 - val_dense_3_accuracy: 0.8973
# Epoch 19/30
# 280/280 [==============================] - 43s 154ms/step - loss: 0.2744 - dense_4_loss: 0.1578 - dense_1_loss: 0.2190 - dense_3_loss: 0.1699 - dense_4_accuracy: 0.9441 - dense_1_accuracy: 0.9200 - dense_3_accuracy: 0.9367 - val_loss: 0.3612 - val_dense_4_loss: 0.2211 - val_dense_1_loss: 0.2396 - val_dense_3_loss: 0.2272 - val_dense_4_accuracy: 0.9156 - val_dense_1_accuracy: 0.9109 - val_dense_3_accuracy: 0.9156
# Epoch 20/30
# 280/280 [==============================] - 43s 155ms/step - loss: 0.2677 - dense_4_loss: 0.1548 - dense_1_loss: 0.2110 - dense_3_loss: 0.1651 - dense_4_accuracy: 0.9428 - dense_1_accuracy: 0.9235 - dense_3_accuracy: 0.9395 - val_loss: 0.4940 - val_dense_4_loss: 0.3144 - val_dense_1_loss: 0.2884 - val_dense_3_loss: 0.3105 - val_dense_4_accuracy: 0.9026 - val_dense_1_accuracy: 0.9065 - val_dense_3_accuracy: 0.8994
# Epoch 21/30
# 280/280 [==============================] - 44s 156ms/step - loss: 0.2480 - dense_4_loss: 0.1416 - dense_1_loss: 0.1985 - dense_3_loss: 0.1561 - dense_4_accuracy: 0.9475 - dense_1_accuracy: 0.9265 - dense_3_accuracy: 0.9421 - val_loss: 0.3543 - val_dense_4_loss: 0.2151 - val_dense_1_loss: 0.2264 - val_dense_3_loss: 0.2377 - val_dense_4_accuracy: 0.9232 - val_dense_1_accuracy: 0.9229 - val_dense_3_accuracy: 0.9216
# Epoch 22/30
# 280/280 [==============================] - 44s 155ms/step - loss: 0.2313 - dense_4_loss: 0.1312 - dense_1_loss: 0.1864 - dense_3_loss: 0.1472 - dense_4_accuracy: 0.9550 - dense_1_accuracy: 0.9340 - dense_3_accuracy: 0.9480 - val_loss: 0.4019 - val_dense_4_loss: 0.2467 - val_dense_1_loss: 0.2559 - val_dense_3_loss: 0.2614 - val_dense_4_accuracy: 0.9122 - val_dense_1_accuracy: 0.9135 - val_dense_3_accuracy: 0.9133
# Epoch 23/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.2283 - dense_4_loss: 0.1307 - dense_1_loss: 0.1864 - dense_3_loss: 0.1387 - dense_4_accuracy: 0.9528 - dense_1_accuracy: 0.9331 - dense_3_accuracy: 0.9516 - val_loss: 0.3952 - val_dense_4_loss: 0.2491 - val_dense_1_loss: 0.2273 - val_dense_3_loss: 0.2595 - val_dense_4_accuracy: 0.9086 - val_dense_1_accuracy: 0.9224 - val_dense_3_accuracy: 0.9114
# Epoch 24/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.2130 - dense_4_loss: 0.1216 - dense_1_loss: 0.1722 - dense_3_loss: 0.1326 - dense_4_accuracy: 0.9564 - dense_1_accuracy: 0.9387 - dense_3_accuracy: 0.9507 - val_loss: 0.4881 - val_dense_4_loss: 0.3116 - val_dense_1_loss: 0.2859 - val_dense_3_loss: 0.3027 - val_dense_4_accuracy: 0.8963 - val_dense_1_accuracy: 0.9020 - val_dense_3_accuracy: 0.8968
# Epoch 25/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.2132 - dense_4_loss: 0.1222 - dense_1_loss: 0.1718 - dense_3_loss: 0.1318 - dense_4_accuracy: 0.9564 - dense_1_accuracy: 0.9384 - dense_3_accuracy: 0.9517 - val_loss: 0.4058 - val_dense_4_loss: 0.2565 - val_dense_1_loss: 0.2456 - val_dense_3_loss: 0.2522 - val_dense_4_accuracy: 0.9138 - val_dense_1_accuracy: 0.9148 - val_dense_3_accuracy: 0.9146
# Epoch 26/30
# 280/280 [==============================] - 43s 154ms/step - loss: 0.1899 - dense_4_loss: 0.1042 - dense_1_loss: 0.1676 - dense_3_loss: 0.1179 - dense_4_accuracy: 0.9614 - dense_1_accuracy: 0.9403 - dense_3_accuracy: 0.9571 - val_loss: 0.4618 - val_dense_4_loss: 0.2941 - val_dense_1_loss: 0.2691 - val_dense_3_loss: 0.2898 - val_dense_4_accuracy: 0.9148 - val_dense_1_accuracy: 0.9138 - val_dense_3_accuracy: 0.9141
# Epoch 27/30
# 280/280 [==============================] - 43s 155ms/step - loss: 0.2012 - dense_4_loss: 0.1153 - dense_1_loss: 0.1619 - dense_3_loss: 0.1245 - dense_4_accuracy: 0.9598 - dense_1_accuracy: 0.9430 - dense_3_accuracy: 0.9571 - val_loss: 0.3909 - val_dense_4_loss: 0.2466 - val_dense_1_loss: 0.2434 - val_dense_3_loss: 0.2376 - val_dense_4_accuracy: 0.9242 - val_dense_1_accuracy: 0.9180 - val_dense_3_accuracy: 0.9242
# Epoch 28/30
# 280/280 [==============================] - 44s 157ms/step - loss: 0.1749 - dense_4_loss: 0.0968 - dense_1_loss: 0.1520 - dense_3_loss: 0.1082 - dense_4_accuracy: 0.9661 - dense_1_accuracy: 0.9450 - dense_3_accuracy: 0.9606 - val_loss: 0.4508 - val_dense_4_loss: 0.2931 - val_dense_1_loss: 0.2363 - val_dense_3_loss: 0.2891 - val_dense_4_accuracy: 0.9169 - val_dense_1_accuracy: 0.9198 - val_dense_3_accuracy: 0.9161
# Epoch 29/30
# 280/280 [==============================] - 43s 155ms/step - loss: 0.1623 - dense_4_loss: 0.0887 - dense_1_loss: 0.1441 - dense_3_loss: 0.1013 - dense_4_accuracy: 0.9675 - dense_1_accuracy: 0.9486 - dense_3_accuracy: 0.9653 - val_loss: 0.4407 - val_dense_4_loss: 0.2745 - val_dense_1_loss: 0.2440 - val_dense_3_loss: 0.3097 - val_dense_4_accuracy: 0.9159 - val_dense_1_accuracy: 0.9195 - val_dense_3_accuracy: 0.9120
# Epoch 30/30
# 280/280 [==============================] - 43s 153ms/step - loss: 0.1552 - dense_4_loss: 0.0850 - dense_1_loss: 0.1341 - dense_3_loss: 0.0997 - dense_4_accuracy: 0.9700 - dense_1_accuracy: 0.9505 - dense_3_accuracy: 0.9648 - val_loss: 0.4661 - val_dense_4_loss: 0.2965 - val_dense_1_loss: 0.2471 - val_dense_3_loss: 0.3184 - val_dense_4_accuracy: 0.9193 - val_dense_1_accuracy: 0.9203 - val_dense_3_accuracy: 0.9177

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train','Val'])

axs[1].plot(history.history['dense_4_accuracy'])
axs[1].plot(history.history['val_dense_4_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])

# %% [markdown]
# #### Model results

# %%
# save model to S3
s3_save_keras_model(model, f'{model_id}-{data_id}{note}')
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /tmp/tmp41khnyfl/googlenet-paper/assets

# %%
# compute model results on test set
start = time.time()
results = model.evaluate(x_test, y_test)
print("Wall time: {:.2f} seconds".format(time.time() - start))
print(results)
# Out:
# 120/120 [==============================] - 3s 27ms/step - loss: 0.4470 - dense_4_loss: 0.2802 - dense_1_loss: 0.2506 - dense_3_loss: 0.3055 - dense_4_accuracy: 0.9248 - dense_1_accuracy: 0.9211 - dense_3_accuracy: 0.9227
# Wall time: 4.78 seconds
# [0.44704514741897583, 0.2801892161369324, 0.2506416141986847, 0.30554473400115967, 0.92476487159729, 0.9211076498031616, 0.9226750135421753]

# %%
# generate predictions for model analysis
start = time.time()
pred = model.predict(x_test)
y_pred = np.argmax(pred[0], axis=1)
predictions = [y_pred, pred]
print("Wall time: {} seconds".format(time.time() - start))
# Out:
# Wall time: 3.1650097370147705 seconds

# %%
# save predictions
# save to local instance
with open(f'{result_path}/{model_id}-{data_id}{note}.pkl', "wb") as f:
    pickle.dump(predictions, f)

# %%
# plot confusion matrix
helper.plot_confusion_matrix(y_test, y_pred, mode='classify', normalize=True)

# %%
# plot confusion matrix counts
helper.plot_confusion_matrix(y_test, y_pred, mode='classify', normalize=False)
